# %% [markdown]
# ## Creación de un entorno virtual en Python

# %% [markdown]
# Mostramos el resultado de la práctica en la que creamos un entorno virtual, con una captura de pantalla de la terminal

# %%
from PIL import Image
i = Image.open('img/Kata2.png')
i.show()

# %%
from IPython.display import Image
Image('img/Kata2.png')
